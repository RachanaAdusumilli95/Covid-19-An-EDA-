# %% [markdown]
# <a href="https://colab.research.google.com/github/RachanaAdusumilli95/Covid-19-An-EDA-/blob/main/Covid_19_Data_Analysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv('D:/Rachana/covid_19_data.csv', encoding = 'unicode_escape')
df.head()
# Out:
#    S.No  Country  Total Cases   New Cases  Total Deaths  New Deaths  \
# 0     1      USA     106385356        NaN     1157194.0         NaN
# 1     2    India      44776002        NaN      531016.0         NaN
# 2     3   France      39853256        NaN      165857.0         NaN
# 3     4  Germany      38374310        NaN      171597.0         NaN
# 4     5   Brazil      37358092        NaN      700811.0         NaN
#
#    Total Recovered  New Recovered  Active Cases   Serious, Critical  \
# 0      104223424.0            NaN      1004738.0             1714.0
# 1       44204771.0            NaN        40215.0                NaN
# 2       39560173.0            NaN       127226.0              869.0
# 3       38138800.0         5800.0        63913.0                NaN
# 4       36249161.0            NaN       408120.0                NaN
#
#    Tot Cases/1M pop  Deaths/1M pop   Total Tests  Tests/1M pop    Population
# ...

# %%
#checking dataset shape
df.shape
# Out:
# (231, 15)

# %%
columns = df.columns
columns
# Out:
# Index(['S.No', 'Country', 'Total Cases ', 'New Cases', 'Total Deaths',
#        'New Deaths', 'Total Recovered', 'New Recovered', 'Active Cases ',
#        'Serious, Critical', 'Tot Cases/1M pop', 'Deaths/1M pop', 'Total Tests',
#        'Tests/1M pop', 'Population'],
#       dtype='object')

# %%
#deleting unwanted columns

# S.No is not important for us here
df.drop(["S.No"],
                axis=1,
                #default value, annotation axis=0 which is equal to rows
                inplace = True   #will change the corona dataset too
                        )

# %%
df.head()
# Out:
#    Country  Total Cases   New Cases  Total Deaths  New Deaths  \
# 0      USA     106385356        NaN     1157194.0         NaN
# 1    India      44776002        NaN      531016.0         NaN
# 2   France      39853256        NaN      165857.0         NaN
# 3  Germany      38374310        NaN      171597.0         NaN
# 4   Brazil      37358092        NaN      700811.0         NaN
#
#    Total Recovered  New Recovered  Active Cases   Serious, Critical  \
# 0      104223424.0            NaN      1004738.0             1714.0
# 1       44204771.0            NaN        40215.0                NaN
# 2       39560173.0            NaN       127226.0              869.0
# 3       38138800.0         5800.0        63913.0                NaN
# 4       36249161.0            NaN       408120.0                NaN
#
#    Tot Cases/1M pop  Deaths/1M pop   Total Tests  Tests/1M pop    Population
# 0          317753.0         3456.0  1.175419e+09     3510755.0  3.348053e+08
# ...

# %%
df.isnull().sum()
# Out:
# Country                0
# Total Cases            0
# New Cases            207
# Total Deaths           6
# New Deaths           212
# Total Recovered       21
# New Recovered        203
# Active Cases          19
# Serious, Critical    105
# Tot Cases/1M pop       2
# Deaths/1M pop          8
# Total Tests           18
# Tests/1M pop          18
# Population             2
# dtype: int64

# %%
train.shape
# Out:
# (231, 15)

# %%
con_df=df[['Total Deaths','Total Cases ','Country',]].groupby(['Country']).sum()
con_df

# why is this even happening? why is the country not in the same index as total deaths and total cases ??
# Out:
#                    Total Deaths  Total Cases
# Country
# Afghanistan              7896.0        212177
# Albania                  3602.0        334701
# Algeria                  6881.0        271617
# Andorra                   165.0         47930
# Angola                   1934.0        105331
# ...                         ...           ...
# Wallis and Futuna           7.0          3427
# Western Sahara              1.0            10
# Yemen                    2159.0         11945
# Zambia                   4058.0        343753
# Zimbabwe                 5681.0        264555
#
# [231 rows x 2 columns]

# %%
# Finding out Total Deaths out of total cases 
plt.figure(figsize=(7,5))
plt.scatter(con_df['Total Deaths'],con_df['Total Cases '])
# with the below scattar plot we understand that

# %%
#Will apply log scaling to y
x = df["Total Deaths"]
y = df["Total Cases "]
sb.scatterplot(x,np.log(y))

#Now we can see +ve correlation
# Out:
# <AxesSubplot:xlabel='Total Deaths', ylabel='Total Cases '>

# %%
#RegPlot
x = df["Total Cases "]
y = df["Total Deaths"]
sb.regplot(x,np.log(y))

#Line fitted, +ve slope seen 

# My question = what it the graph telling? 
# Ans: I think that the graph conveys that the higher the Total cases are, the higher the Total deaths are. 
# This is a very obvious insights. However, if the data were to be collected over a period of time, 
# we could have understod the corelation much better as we could have gotten a chance to see if the deaths 
# reduces even if the total cases are increased. 

# But we observe that the data points are concentrated when the total cases are lower and less when the total case are higher. 

# How exactly is this chart supposed to be visualized
# Out:
# <AxesSubplot:xlabel='Total Cases ', ylabel='Total Deaths'>

# %%
plt.figure(figsize=(2,1))
df[['Country','Total Cases ']].groupby(['Country']).plot.bar()
plt.show() 

# My  question = How to make all the countries appear in one chart like a regular bar plot. I want to ccompare the deaths across all the countries

# %%
columns = df.columns
columns
# Out:
# Index(['Country', 'Total Cases ', 'New Cases', 'Total Deaths', 'New Deaths',
#        'Total Recovered', 'New Recovered', 'Active Cases ',
#        'Serious, Critical', 'Tot Cases/1M pop', 'Deaths/1M pop', 'Total Tests',
#        'Tests/1M pop', 'Population'],
#       dtype='object')
